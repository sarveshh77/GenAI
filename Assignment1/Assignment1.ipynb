# %%
# !pip install openAI
# !pip install langchain
# !pip install Cohere
# !pip install langchain_community

# %%
from google.colab import userdata

COHERE_API_KEY = userdata.get("COHERE_API_KEY")
print("Key loaded:", COHERE_API_KEY is not None)
# Out:
# Key loaded: True

# %%
import os
import cohere

co = cohere.Client(os.environ.get("COHERE_API_KEY"))


print("Key loaded successfully!")
# Out:
# Key loaded successfully!

# %%
# !pip install -U langchain langchain-cohere cohere

# %%
from google.colab import userdata
from langchain_cohere import ChatCohere
from langchain_core.messages import HumanMessage

llm = ChatCohere(
    model="command-r-08-2024",  # ✅ Valid dated version
    cohere_api_key=userdata.get("COHERE_API_KEY")
)

result = llm.invoke([
    HumanMessage(
        content="What should I include in my diet to stay energetic and make a productive day?"
    )
])

print(result.content)
# Out:
# A balanced and nutritious diet is key to maintaining energy levels and productivity throughout the day. Here are some essential components to include in your diet:
#
# 1. Complex Carbohydrates: Foods like whole grains (oats, brown rice, quinoa), legumes (beans, lentils), and starchy vegetables (sweet potatoes, corn) provide a steady release of energy, keeping you fueled for longer periods.
#
# 2. Lean Proteins: Incorporate sources like chicken, turkey, fish, tofu, and eggs. Proteins are essential for muscle repair and growth, and they also help you feel fuller for longer, preventing energy slumps.
#
# 3. Healthy Fats: Avocados, nuts, seeds, olive oil, and fatty fish like salmon are excellent sources of healthy fats. These provide a concentrated source of energy and are crucial for brain function and overall health.
#
# ...
